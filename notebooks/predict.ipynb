# %%
import pandas as pd

# %%
df = pd.read_csv("nba_games.csv", index_col=0)

# %%
df
# Out:
#           mp   mp.1    fg   fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0      240.0  240.0  36.0  88.0  0.409   8.0  32.0  0.250  19.0  25.0  ...
# 1      240.0  240.0  38.0  83.0  0.458   5.0  22.0  0.227  21.0  25.0  ...
# 2      240.0  240.0  47.0  97.0  0.485  15.0  41.0  0.366  13.0  19.0  ...
# 3      240.0  240.0  43.0  80.0  0.538  16.0  30.0  0.533  19.0  21.0  ...
# 4      240.0  240.0  38.0  76.0  0.500   7.0  21.0  0.333  25.0  30.0  ...
# ...      ...    ...   ...   ...    ...   ...   ...    ...   ...   ...  ...
# 20249  240.0  240.0  42.0  96.0  0.438  15.0  42.0  0.357  10.0  21.0  ...
# 20250  240.0  240.0  40.0  84.0  0.476  15.0  44.0  0.341   3.0   6.0  ...
# 20251  240.0  240.0  46.0  88.0  0.523  14.0  34.0  0.412   3.0   3.0  ...
# 20252  240.0  240.0  46.0  97.0  0.474  14.0  39.0  0.359  12.0  16.0  ...
# 20253  240.0  240.0  43.0  84.0  0.512  11.0  32.0  0.344  28.0  32.0  ...
#
# ...

# %%
df = df.sort_values("date")

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#           mp   mp.1    fg    fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0      240.0  240.0  36.0   88.0  0.409   8.0  32.0  0.250  19.0  25.0  ...
# 1      240.0  240.0  38.0   83.0  0.458   5.0  22.0  0.227  21.0  25.0  ...
# 2      240.0  240.0  47.0   97.0  0.485  15.0  41.0  0.366  13.0  19.0  ...
# 3      240.0  240.0  43.0   80.0  0.538  16.0  30.0  0.533  19.0  21.0  ...
# 4      240.0  240.0  42.0   97.0  0.433   6.0  22.0  0.273  30.0  38.0  ...
# ...      ...    ...   ...    ...    ...   ...   ...    ...   ...   ...  ...
# 20249  240.0  240.0  32.0   85.0  0.376  11.0  39.0  0.282  11.0  18.0  ...
# 20250  240.0  240.0  47.0   88.0  0.534  17.0  40.0  0.425   6.0  10.0  ...
# 20251  240.0  240.0  40.0   88.0  0.455  15.0  35.0  0.429  10.0  15.0  ...
# 20252  240.0  240.0  52.0  104.0  0.500  15.0  41.0  0.366  13.0  15.0  ...
# 20253  240.0  240.0  43.0   84.0  0.512  11.0  32.0  0.344  28.0  32.0  ...
#
# ...

# %%
del df["mp.1"]
del df["mp_opp.1"]
del df["index_opp"]

# %%
df = df.copy()
def add_target(team):
    team["target"] = team["won"].shift(-1)
    return team
df["target"] = df.groupby("team")["won"].shift(-1)

# %%
df["team"]
# Out:
# 0        BOS
# 1        CLE
# 2        HOU
# 3        GSW
# 4        WAS
#         ...
# 20249    CHO
# 20250    ATL
# 20251    ORL
# 20252    MEM
# 20253    SAS
# Name: team, Length: 20254, dtype: object

# %%
df[df["team"]=="WAS"]
# Out:
#           mp    fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 4      240.0  42.0  97.0  0.433   6.0  22.0  0.273  30.0  38.0  0.789  ...
# 33     240.0  40.0  75.0  0.533   6.0  17.0  0.353  29.0  35.0  0.829  ...
# 91     240.0  37.0  84.0  0.440   9.0  30.0  0.300  26.0  28.0  0.929  ...
# 108    265.0  39.0  95.0  0.411   6.0  26.0  0.231  15.0  23.0  0.652  ...
# 147    240.0  43.0  97.0  0.443  15.0  33.0  0.455  16.0  22.0  0.727  ...
# ...      ...   ...   ...    ...   ...   ...    ...   ...   ...    ...  ...
# 20136  240.0  35.0  86.0  0.407  12.0  45.0  0.267   8.0  10.0  0.800  ...
# 20161  240.0  38.0  91.0  0.418  11.0  39.0  0.282  11.0  15.0  0.733  ...
# 20165  240.0  34.0  87.0  0.391  10.0  33.0  0.303  25.0  30.0  0.833  ...
# 20213  240.0  35.0  91.0  0.385  10.0  41.0  0.244   9.0  12.0  0.750  ...
# 20237  240.0  46.0  90.0  0.511  16.0  37.0  0.432  11.0  17.0  0.647  ...
#
# ...

# %%
df["target"][pd.isnull(df["target"])] = 2
# Out:
# C:\Users\tahsi\AppData\Local\Temp\ipykernel_33832\1618397414.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["target"][pd.isnull(df["target"])] = 2

# %%
df["target"] = df["target"].astype(int, errors="ignore")

# %%
df
# Out:
#           mp    fg    fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 0      240.0  36.0   88.0  0.409   8.0  32.0  0.250  19.0  25.0  0.760  ...
# 1      240.0  38.0   83.0  0.458   5.0  22.0  0.227  21.0  25.0  0.840  ...
# 2      240.0  47.0   97.0  0.485  15.0  41.0  0.366  13.0  19.0  0.684  ...
# 3      240.0  43.0   80.0  0.538  16.0  30.0  0.533  19.0  21.0  0.905  ...
# 4      240.0  42.0   97.0  0.433   6.0  22.0  0.273  30.0  38.0  0.789  ...
# ...      ...   ...    ...    ...   ...   ...    ...   ...   ...    ...  ...
# 20249  240.0  32.0   85.0  0.376  11.0  39.0  0.282  11.0  18.0  0.611  ...
# 20250  240.0  47.0   88.0  0.534  17.0  40.0  0.425   6.0  10.0  0.600  ...
# 20251  240.0  40.0   88.0  0.455  15.0  35.0  0.429  10.0  15.0  0.667  ...
# 20252  240.0  52.0  104.0  0.500  15.0  41.0  0.366  13.0  15.0  0.867  ...
# 20253  240.0  43.0   84.0  0.512  11.0  32.0  0.344  28.0  32.0  0.875  ...
#
# ...

# %%
df["won"].value_counts()
# Out:
# won
# False    10127
# True     10127
# Name: count, dtype: int64

# %%
df["target"].value_counts()
# Out:
# target
# 0    10112
# 1    10112
# 2       30
# Name: count, dtype: int64

# %%
nulls = pd.isnull(df)

# %%
nulls = nulls.sum()

# %%
nulls = nulls[nulls>0]

# %%
nulls
# Out:
# ft%                 1
# gmsc            20254
# +/-             20254
# mp_max          20254
# mp_max.1        20254
# ft%_max             1
# +/-_max            15
# ft%_opp             1
# gmsc_opp        20254
# +/-_opp         20254
# mp_max_opp      20254
# mp_max_opp.1    20254
# ft%_max_opp         1
# +/-_max_opp        15
# dtype: int64

# %%
big_nulls = nulls[nulls==19530]

# %%
big_nulls
# Out:
# Series([], dtype: int64)

# %%
nulls
# Out:
# ft%                 1
# gmsc            20254
# +/-             20254
# mp_max          20254
# mp_max.1        20254
# ft%_max             1
# +/-_max            15
# ft%_opp             1
# gmsc_opp        20254
# +/-_opp         20254
# mp_max_opp      20254
# mp_max_opp.1    20254
# ft%_max_opp         1
# +/-_max_opp        15
# dtype: int64

# %%
valid_columns = df.columns[~df.columns.isin(big_nulls.index)]

# %%
valid_columns
# Out:
# Index(['mp', 'fg', 'fga', 'fg%', '3p', '3pa', '3p%', 'ft', 'fta', 'ft%',
#        ...
#        'usg%_max_opp', 'ortg_max_opp', 'drtg_max_opp', 'team_opp', 'total_opp',
#        'home_opp', 'seasons', 'date', 'won', 'target'],
#       dtype='object', length=152)

# %%
df = df[valid_columns].copy()

# %%
df
# Out:
#           mp    fg    fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 0      240.0  36.0   88.0  0.409   8.0  32.0  0.250  19.0  25.0  0.760  ...
# 1      240.0  38.0   83.0  0.458   5.0  22.0  0.227  21.0  25.0  0.840  ...
# 2      240.0  47.0   97.0  0.485  15.0  41.0  0.366  13.0  19.0  0.684  ...
# 3      240.0  43.0   80.0  0.538  16.0  30.0  0.533  19.0  21.0  0.905  ...
# 4      240.0  42.0   97.0  0.433   6.0  22.0  0.273  30.0  38.0  0.789  ...
# ...      ...   ...    ...    ...   ...   ...    ...   ...   ...    ...  ...
# 20249  240.0  32.0   85.0  0.376  11.0  39.0  0.282  11.0  18.0  0.611  ...
# 20250  240.0  47.0   88.0  0.534  17.0  40.0  0.425   6.0  10.0  0.600  ...
# 20251  240.0  40.0   88.0  0.455  15.0  35.0  0.429  10.0  15.0  0.667  ...
# 20252  240.0  52.0  104.0  0.500  15.0  41.0  0.366  13.0  15.0  0.867  ...
# 20253  240.0  43.0   84.0  0.512  11.0  32.0  0.344  28.0  32.0  0.875  ...
#
# ...

# %%
nulls = pd.isnull(df)
nulls = nulls.sum()
nulls = nulls[nulls>0]
nulls
# Out:
# ft%                 1
# gmsc            20254
# +/-             20254
# mp_max          20254
# mp_max.1        20254
# ft%_max             1
# +/-_max            15
# ft%_opp             1
# gmsc_opp        20254
# +/-_opp         20254
# mp_max_opp      20254
# mp_max_opp.1    20254
# ft%_max_opp         1
# +/-_max_opp        15
# dtype: int64

# %%
nulls = df.isnull().sum()
nulls = nulls[nulls > 0]

# 🔽 Put this next
cols_to_drop = nulls[nulls > 15].index
df.drop(columns=cols_to_drop, inplace=True)

# %%
nulls = df.isnull().sum()
nulls = nulls[nulls > 0]

# %%
cols_to_check = nulls.index.tolist()
df = df.dropna(subset=cols_to_check)

# %%
nulls = pd.isnull(df)
nulls = nulls.sum()
nulls = nulls[nulls>0]
nulls
# Out:
# Series([], dtype: int64)

# %%
df
# Out:
#           mp    fg    fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 0      240.0  36.0   88.0  0.409   8.0  32.0  0.250  19.0  25.0  0.760  ...
# 1      240.0  38.0   83.0  0.458   5.0  22.0  0.227  21.0  25.0  0.840  ...
# 2      240.0  47.0   97.0  0.485  15.0  41.0  0.366  13.0  19.0  0.684  ...
# 3      240.0  43.0   80.0  0.538  16.0  30.0  0.533  19.0  21.0  0.905  ...
# 4      240.0  42.0   97.0  0.433   6.0  22.0  0.273  30.0  38.0  0.789  ...
# ...      ...   ...    ...    ...   ...   ...    ...   ...   ...    ...  ...
# 20249  240.0  32.0   85.0  0.376  11.0  39.0  0.282  11.0  18.0  0.611  ...
# 20250  240.0  47.0   88.0  0.534  17.0  40.0  0.425   6.0  10.0  0.600  ...
# 20251  240.0  40.0   88.0  0.455  15.0  35.0  0.429  10.0  15.0  0.667  ...
# 20252  240.0  52.0  104.0  0.500  15.0  41.0  0.366  13.0  15.0  0.867  ...
# 20253  240.0  43.0   84.0  0.512  11.0  32.0  0.344  28.0  32.0  0.875  ...
#
# ...

# %%
# %pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import RidgeClassifier

rr=RidgeClassifier(alpha=1)

split = TimeSeriesSplit(n_splits=3)
sfs = SequentialFeatureSelector(rr, n_features_to_select=30, direction = "forward", cv=split)

# %%
#columns we aren't going to scale
removed_columns = ["seasons", "date", "won", "target", "team", "team_opp"]

# %%
#columns we do scale
selected_columns = df.columns[~df.columns.isin(removed_columns)]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[selected_columns]=scaler.fit_transform(df[selected_columns])
# Out:
# C:\Users\tahsi\AppData\Local\Temp\ipykernel_33832\1350979795.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[selected_columns]=scaler.fit_transform(df[selected_columns])

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0  0.340909  0.409836  0.333333  0.250000  0.366667  0.246819
# 1      0.0  0.386364  0.327869  0.450000  0.142857  0.200000  0.217557
# 2      0.0  0.590909  0.557377  0.514286  0.500000  0.516667  0.394402
# 3      0.0  0.500000  0.278689  0.640476  0.535714  0.333333  0.606870
# 4      0.0  0.477273  0.557377  0.390476  0.178571  0.200000  0.276081
# ...    ...       ...       ...       ...       ...       ...       ...
# 20249  0.0  0.250000  0.360656  0.254762  0.357143  0.483333  0.287532
# 20250  0.0  0.590909  0.409836  0.630952  0.571429  0.500000  0.469466
# 20251  0.0  0.431818  0.409836  0.442857  0.500000  0.416667  0.474555
# 20252  0.0  0.704545  0.672131  0.550000  0.500000  0.516667  0.394402
# 20253  0.0  0.500000  0.344262  0.578571  0.357143  0.366667  0.366412
#
#              ft       fta       ft%  ...  usg%_max_opp  ortg_max_opp  \
# ...

# %%
sfs.fit(df[selected_columns], df["target"])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=1),
#                           n_features_to_select=30)

# %%
predictors = list(selected_columns[sfs.get_support()])

# %%
predictors
# Out:
# ['tov',
#  'pf',
#  'usg%',
#  'ortg',
#  'fta_max',
#  '+/-_max',
#  'ftr_max',
#  'orb%_max',
#  'stl%_max',
#  'drtg_max',
#  'fg_opp',
#  'fg%_opp',
#  '3pa_opp',
#  '3p%_opp',
#  'trb_opp',
#  'ts%_opp',
#  'stl%_opp',
#  'blk%_opp',
#  'usg%_opp',
#  'drtg_opp',
#  'ft_max_opp',
#  'ft%_max_opp',
#  'ast_max_opp',
#  'ts%_max_opp',
#  'efg%_max_opp',
#  'drb%_max_opp',
#  'ast%_max_opp',
#  'stl%_max_opp',
#  'usg%_max_opp',
#  'ortg_max_opp']

# %%
df.rename(columns={"seasons": "season"}, inplace=True)
# Out:
# C:\Users\tahsi\AppData\Local\Temp\ipykernel_33832\1178497399.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"seasons": "season"}, inplace=True)

# %%
def backtest(data, model, predictors, start=2, step=1):
    all_predictions = []
    seasons = sorted(data["season"].unique())
    for i in range(start, len(seasons),step):
        season = seasons[i]
        train = data[data["season"] < season]
        test=data[data["season"] == season]
        model.fit(train[predictors], train["target"])
        preds = model.predict(test[predictors])#default numpyarray return
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"], preds], axis=1)
        combined.columns = ["actual", "prediction"]
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
sorted(df["season"].unique())
# Out:
# [2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025]

# %%
predictions = backtest(df, rr, predictors)

# %%
predictions
# Out:
#        actual  prediction
# 5240        0           1
# 5241        0           0
# 5242        1           0
# 5243        1           1
# 5244        1           1
# ...       ...         ...
# 20249       2           0
# 20250       2           1
# 20251       2           1
# 20252       2           1
# 20253       2           1
#
# [14996 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score
predictions = predictions[predictions["actual"] != 2]
accuracy_score(predictions["actual"], predictions["prediction"])
# Out:
# 0.5513163169851664

# %%
df.groupby("home").apply(lambda x: x[x["won"] == 1].shape[0] / x.shape[0])
# Out:
# home
# 0.0    0.438031
# 1.0    0.561969
# dtype: float64

# %%
df_rolling = df[list(selected_columns) + ["won", "team", "season"]]

# %%
df_rolling
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0  0.340909  0.409836  0.333333  0.250000  0.366667  0.246819
# 1      0.0  0.386364  0.327869  0.450000  0.142857  0.200000  0.217557
# 2      0.0  0.590909  0.557377  0.514286  0.500000  0.516667  0.394402
# 3      0.0  0.500000  0.278689  0.640476  0.535714  0.333333  0.606870
# 4      0.0  0.477273  0.557377  0.390476  0.178571  0.200000  0.276081
# ...    ...       ...       ...       ...       ...       ...       ...
# 20249  0.0  0.250000  0.360656  0.254762  0.357143  0.483333  0.287532
# 20250  0.0  0.590909  0.409836  0.630952  0.571429  0.500000  0.469466
# 20251  0.0  0.431818  0.409836  0.442857  0.500000  0.416667  0.474555
# 20252  0.0  0.704545  0.672131  0.550000  0.500000  0.516667  0.394402
# 20253  0.0  0.500000  0.344262  0.578571  0.357143  0.366667  0.366412
#
#              ft       fta       ft%  ...  blk%_max_opp  tov%_max_opp  \
# ...

# %%
def find_team_averages(team):
    numeric_cols = team.select_dtypes(include=["number"])  
    rolling = numeric_cols.rolling(10).mean() 
    return rolling

df_rolling = df.groupby(["team", "season"], group_keys=False).apply(find_team_averages)

# %%
df_rolling
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...    ...       ...       ...       ...       ...       ...       ...
# 20249  0.0  0.363636  0.367213  0.397857  0.342857  0.405000  0.323155
# 20250  0.0  0.547727  0.447541  0.550476  0.517857  0.508333  0.413359
# 20251  0.0  0.427273  0.368852  0.466429  0.428571  0.433333  0.381807
# 20252  0.0  0.495455  0.465574  0.472381  0.496429  0.511667  0.399364
# 20253  0.0  0.452273  0.406557  0.472143  0.485714  0.493333  0.397710
#
#              ft       fta       ft%  ...  stl%_max_opp  blk%_max_opp  \
# ...

# %%
rolling_cols= [f"{col}_10" for col in df_rolling.columns]
df_rolling.columns = rolling_cols
df = pd.concat([df, df_rolling], axis=1)

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0  0.340909  0.409836  0.333333  0.250000  0.366667  0.246819
# 1      0.0  0.386364  0.327869  0.450000  0.142857  0.200000  0.217557
# 2      0.0  0.590909  0.557377  0.514286  0.500000  0.516667  0.394402
# 3      0.0  0.500000  0.278689  0.640476  0.535714  0.333333  0.606870
# 4      0.0  0.477273  0.557377  0.390476  0.178571  0.200000  0.276081
# ...    ...       ...       ...       ...       ...       ...       ...
# 20249  0.0  0.250000  0.360656  0.254762  0.357143  0.483333  0.287532
# 20250  0.0  0.590909  0.409836  0.630952  0.571429  0.500000  0.469466
# 20251  0.0  0.431818  0.409836  0.442857  0.500000  0.416667  0.474555
# 20252  0.0  0.704545  0.672131  0.550000  0.500000  0.516667  0.394402
# 20253  0.0  0.500000  0.344262  0.578571  0.357143  0.366667  0.366412
#
#              ft       fta       ft%  ...  stl%_max_opp_10  blk%_max_opp_10  \
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 256    0.0  0.295455  0.409836  0.278571  0.285714  0.400000  0.265903
# 259    0.0  0.477273  0.426230  0.483333  0.535714  0.616667  0.361323
# 261    0.0  0.431818  0.393443  0.454762  0.321429  0.283333  0.399491
# 264    0.0  0.431818  0.262295  0.564286  0.428571  0.233333  0.618321
# 265    0.0  0.431818  0.393443  0.454762  0.178571  0.233333  0.246819
# ...    ...       ...       ...       ...       ...       ...       ...
# 20249  0.0  0.250000  0.360656  0.254762  0.357143  0.483333  0.287532
# 20250  0.0  0.590909  0.409836  0.630952  0.571429  0.500000  0.469466
# 20251  0.0  0.431818  0.409836  0.442857  0.500000  0.416667  0.474555
# 20252  0.0  0.704545  0.672131  0.550000  0.500000  0.516667  0.394402
# 20253  0.0  0.500000  0.344262  0.578571  0.357143  0.366667  0.366412
#
#              ft       fta       ft%  ...  stl%_max_opp_10  blk%_max_opp_10  \
# ...

# %%
def shift_col(team, col_name):
    next_col = team[col_name].shift(-1)
    return next_col
def add_col(df, col_name):
    return df.groupby("team", group_keys=False).apply(lambda x:shift_col(x,col_name))
df["home_next"] = add_col(df, "home") #next game
df["team_opp_next"] = add_col(df, "team_opp")
df["date_next"] = add_col(df, "date")
# Out:
# C:\Users\tahsi\AppData\Local\Temp\ipykernel_33832\4130912735.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["home_next"] = add_col(df, "home") #next game
# C:\Users\tahsi\AppData\Local\Temp\ipykernel_33832\4130912735.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["team_opp_next"] = add_col(df, "team_opp")
# C:\Users\tahsi\AppData\Local\Temp\ipykernel_33832\4130912735.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 256    0.0  0.295455  0.409836  0.278571  0.285714  0.400000  0.265903
# 259    0.0  0.477273  0.426230  0.483333  0.535714  0.616667  0.361323
# 261    0.0  0.431818  0.393443  0.454762  0.321429  0.283333  0.399491
# 264    0.0  0.431818  0.262295  0.564286  0.428571  0.233333  0.618321
# 265    0.0  0.431818  0.393443  0.454762  0.178571  0.233333  0.246819
# ...    ...       ...       ...       ...       ...       ...       ...
# 20249  0.0  0.250000  0.360656  0.254762  0.357143  0.483333  0.287532
# 20250  0.0  0.590909  0.409836  0.630952  0.571429  0.500000  0.469466
# 20251  0.0  0.431818  0.409836  0.442857  0.500000  0.416667  0.474555
# 20252  0.0  0.704545  0.672131  0.550000  0.500000  0.516667  0.394402
# 20253  0.0  0.500000  0.344262  0.578571  0.357143  0.366667  0.366412
#
#              ft       fta       ft%  ...  usg%_max_opp_10  ortg_max_opp_10  \
# ...

# %%
df = df.copy()

# %%
full = df.merge(
    df[rolling_cols + ["team_opp_next", "date_next", "team"]],
    left_on=["team", "date_next"], 
    right_on=["team_opp_next", "date_next"]
)

# %%
full
# Out:
#          mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.00  0.431818  0.262295  0.564286  0.428571  0.233333  0.618321
# 1      0.00  0.431818  0.393443  0.454762  0.178571  0.233333  0.246819
# 2      0.25  0.318182  0.393443  0.316667  0.285714  0.350000  0.297710
# 3      0.00  0.363636  0.180328  0.550000  0.214286  0.166667  0.374046
# 4      0.00  0.272727  0.459016  0.223810  0.178571  0.316667  0.192112
# ...     ...       ...       ...       ...       ...       ...       ...
# 17957  0.00  0.568182  0.491803  0.538095  0.607143  0.483333  0.516539
# 17958  0.00  0.636364  0.360656  0.730952  0.428571  0.366667  0.445293
# 17959  0.00  0.431818  0.426230  0.428571  0.392857  0.316667  0.455471
# 17960  0.00  0.454545  0.442623  0.445238  0.607143  0.683333  0.377863
# 17961  0.00  0.522727  0.459016  0.511905  0.142857  0.233333  0.193384
#
#              ft       fta       ft%  ...  tov%_max_opp_10_y  \
# ...

# %%
full[["team_x", "team_opp_next_x", "team_y", "team_opp_next_y", "date_next"]]
# Out:
#       team_x team_opp_next_x team_y team_opp_next_y   date_next
# 0        DET             IND    IND             DET  2017-11-08
# 1        DEN             BRK    BRK             DEN  2017-11-07
# 2        NOP             IND    IND             NOP  2017-11-07
# 3        POR             MEM    MEM             POR  2017-11-07
# 4        ORL             NYK    NYK             ORL  2017-11-08
# ...      ...             ...    ...             ...         ...
# 17957    DET             MIL    MIL             DET  2025-04-13
# 17958    ORL             ATL    ATL             ORL  2025-04-13
# 17959    IND             CLE    CLE             IND  2025-04-13
# 17960    HOU             DEN    DEN             HOU  2025-04-13
# 17961    DEN             HOU    HOU             DEN  2025-04-13
#
# [17962 rows x 5 columns]

# %%
removed_columns = list(full.columns[full.dtypes == "object"]) + removed_columns

# %%
#full.columns[full.dtypes == "object"]

# %%
removed_columns
# Out:
# ['team_x',
#  'team_opp',
#  'date',
#  'team_opp_next_x',
#  'date_next',
#  'team_opp_next_y',
#  'team_y',
#  'seasons',
#  'date',
#  'won',
#  'target',
#  'team',
#  'team_opp']

# %%
selected_columns = full.columns[~full.columns.isin(removed_columns)]

# %%
sfs.fit(full[selected_columns], full["target"])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=1),
#                           n_features_to_select=30)

# %%
predictors = list(selected_columns[sfs.get_support()])

# %%
predictors
# Out:
# ['blk',
#  'blk%',
#  'tov%',
#  'usg%',
#  'blk%_max',
#  'ortg_max',
#  'ts%_opp',
#  'usg%_opp',
#  'usg%_max_opp',
#  'ortg_max_opp',
#  'drtg_max_opp',
#  '3p%_10_x',
#  'usg%_10_x',
#  'drb_max_10_x',
#  'pts_max_10_x',
#  '+/-_max_10_x',
#  'usg%_max_10_x',
#  'ts%_opp_10_x',
#  'usg%_opp_10_x',
#  'blk_max_opp_10_x',
#  '+/-_max_opp_10_x',
#  'target_10_x',
#  'home_next',
#  'usg%_10_y',
#  '+/-_max_10_y',
#  'ast%_max_10_y',
#  '3p_opp_10_y',
#  'usg%_opp_10_y',
#  '+/-_max_opp_10_y',
#  'target_10_y']

# %%
predictions = backtest(full, rr, predictors)

# %%
accuracy_score(predictions["actual"],predictions["prediction"])
# Out:
# 0.7817155756207675

# %%
#how to continue to improve accuracy
#try using more powerful than ridge regression model like random forest classifier
#try out different numbers of features you're selecting for the model (like last 15 games or last 20 games or last 5 games)

# %%
#for future get most up to date data 
#fill in home_next, team_opp_next, date_next
#rerun 
#look at any rows with target value 2, find predictions based on that
